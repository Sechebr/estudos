# %%
email = input('digite seu email: ')
senha = int(input('digite sua senha: '))

if senha==32:
  print(f'Senha esta correta')
else:
  print('Senha está incorreta')
# Out:
# digite seu email: filipe
# digite sua senha: 34
# Senha está incorreta
